# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(
df, test_size=0.33, random_state=42)

# %%
X_test.shape
# Out:
# (295, 16)

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import seaborn as sns
sns.countplot(df, x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
import seaborn as sns
sns.countplot(df, x='Sex', hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender2label = {'male': 0, 'female': 1}
df['Sex_Code'] = df['Sex'].apply(lambda x: gender2label[x])

# %%
X = df.drop(labels=['Survived','PassengerId'],axis=1)
Y = df['Survived']

# %%
from sklearn.ensemble import RandomForestClassifier
Base = ['Sex_Code','Pclass']
Base_Model = RandomForestClassifier(random_state=2,
                                    n_estimators=250,
                                    min_samples_split=20,
                                    oob_score=True)
Base_Model.fit(X[Base], Y)
print('Base oob score :%.5f' %(Base_Model.oob_score_))
# Out:
# Base oob score :0.73176

# %%
df['IsAge'] = df['Age'].isnull().apply(lambda x: 1 if x is True else 0)

# %%
import seaborn as sns
sns.countplot(df, x='Sex', hue='IsAge')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
import seaborn as sns
sns.countplot(df, x='Pclass', hue='IsAge')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
import warnings
warnings.filterwarnings("ignore")

df_sur = df[df['Survived']==1][df['Pclass']!=3]['Age']
df_unsur = df[df['Survived']!=1][df['Pclass']!=3]['Age']

sns.distplot(df_sur, label='Survived', bins=10)
sns.distplot(df_unsur, label='Dead', bins=10)
plt.legend()

# %%
df.Age.median()
# Out:
# 28.0

# %%
df['Age_impute'] = df['Age'].fillna(df.Age.median())

# %%
df['Age_Code'] = df['Age_impute'].apply(lambda x: 1 if x > 18 else 0)

# %%
X = df.drop(labels=['Survived','PassengerId'],axis=1)
Y = df['Survived']

# %%
from sklearn.ensemble import RandomForestClassifier
Base = ['Sex_Code','Pclass', 'Age_Code']
Base_Model = RandomForestClassifier(random_state=2,
                                    n_estimators=250,
                                    min_samples_split=20,
                                    oob_score=True)
Base_Model.fit(X[Base], Y)
print('Base oob score :%.5f' %(Base_Model.oob_score_))
# Out:
# Base oob score :0.76431

# %%
import matplotlib.pyplot as plt
import numpy as np
importances = Base_Model.feature_importances_
std = np.std([tree.feature_importances_ for tree in Base_Model.estimators_], axis=0)

import pandas as pd

forest_importances = pd.Series(importances, index=['Sex_Code','Pclass', 'Age_Code'])

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")

df_sur = df[df['Survived']==1]['Fare']
df_unsur = df[df['Survived']!=1]['Fare']

sns.distplot(df_sur, label='Survived', bins=10)
sns.distplot(df_unsur, label='Dead', bins=10)
plt.legend()
